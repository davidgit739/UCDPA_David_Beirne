# %%
#import required packages 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
rawdata_1 = pd.ExcelFile('C:/Users/David/Desktop/UCD/Assignment/Data/lookback_mkt.xlsx') #import data from .xlsx
auctions_to_1 = pd.read_excel(rawdata_1, 'auctions_to')#create a pandas data frame from specific sheet within .xlsx file

# %%
print(auctions_to_1.shape)
# Out:
# (88863, 18)

# %%
rawdata_2 = pd.ExcelFile('C:/Users/David/Desktop/UCD/Assignment/Data/Lookback2_mkt.xlsx') #import data from .xlsx
auctions_to_2 = pd.read_excel(rawdata_2, 'auctions_to')#create a pandas data frame from specific sheet within .xlsx file

# %%
print(auctions_to_2.shape)
# Out:
# (52353, 18)

# %%
print(auctions_to_1.head())
print(auctions_to_1.tail())
# Out:
#   auction             timestamp  price_eur  price_gbp  ni_vols  ni_netpos  \
# 0     DAM  2018-09-30T22:00:00Z     71.267     63.620    591.3     -286.0
# 1     DAM  2018-09-30T23:00:00Z     67.212     60.000    551.4     -448.4
# 2     DAM  2018-10-01T00:00:00Z     60.500     54.008    512.7     -432.2
# 3     DAM  2018-10-01T01:00:00Z     63.682     56.848    525.3     -464.0
# 4     DAM  2018-10-01T02:00:00Z     71.617     63.932    501.4     -446.6
#
#    roi_vols  roi_netpos DeliveryDate  DeliveryHour  DeliveryInterval  \
# 0    2489.9      -215.7   2018-10-01             1                 1
# 1    2709.7      -457.1   2018-10-01             2                 1
# 2    2480.2      -473.3   2018-10-01             3                 1
# 3    2397.0      -438.4   2018-10-01             4                 1
# 4    2376.4      -220.0   2018-10-01             5                 1
#
#    semo_vols  doy  dow  week  dom      Month  year
# 0     3081.2  274    1    40    1 2018-10-01  2018
# 1     3261.1  274    1    40    1 2018-10-01  2018
# 2     2992.9  274    1    40    1 2018-10-01  2018
# 3     2922.3  274    1    40    1 2018-10-01  2018
# 4     2877.8  274    1    40    1 2018-10-01  2018
#       auction             timestamp  price_eur  price_gbp  ni_vols  ni_netpos  \
# 88858    IDA3  2020-12-31T20:30:00Z       58.0     52.498      2.9        2.1
# 88859    IDA3  2020-12-31T21:00:00Z       63.0     57.024      3.4       -2.6
# 88860    IDA3  2020-12-31T21:30:00Z       45.0     40.731      3.1        2.1
# 88861    IDA3  2020-12-31T22:00:00Z       57.0     51.593      5.7       -5.5
# 88862    IDA3  2020-12-31T22:30:00Z       55.0     49.783      4.4        3.5
#
#        roi_vols  roi_netpos DeliveryDate  DeliveryHour  DeliveryInterval  \
# 88858      65.4        -2.1   2020-12-31            22                 2
# 88859      71.1         2.6   2020-12-31            23                 1
# 88860      89.7        -2.1   2020-12-31            23                 2
# 88861      70.6         5.5   2020-12-31            24                 1
# 88862      79.2        -3.5   2020-12-31            24                 2
#
#        semo_vols  doy  dow  week  dom      Month  year
# 88858       68.3  366    4    53   31 2020-12-01  2020
# 88859       74.5  366    4    53   31 2020-12-01  2020
# 88860       92.8  366    4    53   31 2020-12-01  2020
# 88861       76.3  366    4    53   31 2020-12-01  2020
# 88862       83.6  366    4    53   31 2020-12-01  2020

# %%
print(auctions_to_2.head())
print(auctions_to_2.tail())
# Out:
#   auction             timestamp  price_eur  price_gbp  ni_vols  ni_netpos  \
# 0     DAM  2020-12-31T23:00:00Z      55.09     49.595    739.2     -126.3
# 1     DAM  2021-01-01T00:00:00Z      54.02     48.632    730.7     -150.2
# 2     DAM  2021-01-01T01:00:00Z      53.00     47.713    752.6     -180.1
# 3     DAM  2021-01-01T02:00:00Z      51.24     46.129    704.9     -184.2
# 4     DAM  2021-01-01T03:00:00Z      48.13     43.329    665.3     -154.6
#
#    roi_vols  roi_netpos DeliveryDate  DeliveryHour  DeliveryInterval  \
# 0    3727.3       126.3   2021-01-01             1                 1
# 1    3501.8       150.2   2021-01-01             2                 1
# 2    3423.8       180.1   2021-01-01             3                 1
# 3    3189.3       184.2   2021-01-01             4                 1
# 4    2990.3       154.6   2021-01-01             5                 1
#
#    semo_vols  doy  dow  week  dom      Month  year
# 0     4466.5    1    5     1    1 2021-01-01  2021
# 1     4232.5    1    5     1    1 2021-01-01  2021
# 2     4176.4    1    5     1    1 2021-01-01  2021
# 3     3894.2    1    5     1    1 2021-01-01  2021
# 4     3655.6    1    5     1    1 2021-01-01  2021
#       auction             timestamp  price_eur  price_gbp  ni_vols  ni_netpos  \
# 52348    IDA3  2022-04-30T19:30:00Z     84.388     70.950     30.0      -10.9
# 52349    IDA3  2022-04-30T20:00:00Z     84.388     70.950     22.4       -9.2
# 52350    IDA3  2022-04-30T20:30:00Z     60.000     50.446     21.4       -8.9
# 52351    IDA3  2022-04-30T21:00:00Z     50.000     42.038     21.2       -8.2
# 52352    IDA3  2022-04-30T21:30:00Z     41.000     34.471     21.2       -7.3
#
#        roi_vols  roi_netpos DeliveryDate  DeliveryHour  DeliveryInterval  \
# 52348     182.4        10.9   2022-04-30            22                 2
# 52349      45.1         9.2   2022-04-30            23                 1
# 52350      42.8         8.9   2022-04-30            23                 2
# 52351      41.6         8.2   2022-04-30            24                 1
# 52352      45.7         7.3   2022-04-30            24                 2
#
#        semo_vols  doy  dow  week  dom      Month  year
# 52348      212.4  120    6    18   30 2022-04-01  2022
# 52349       67.5  120    6    18   30 2022-04-01  2022
# 52350       64.2  120    6    18   30 2022-04-01  2022
# 52351       62.8  120    6    18   30 2022-04-01  2022
# 52352       66.9  120    6    18   30 2022-04-01  2022

# %%
print(auctions_to_1.info()) # non-null count demonstrates there are no missing records from the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88863 entries, 0 to 88862
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   auction           88863 non-null  object
#  1   timestamp         88863 non-null  object
#  2   price_eur         88863 non-null  float64
#  3   price_gbp         88863 non-null  float64
#  4   ni_vols           88863 non-null  float64
#  5   ni_netpos         88863 non-null  float64
#  6   roi_vols          88863 non-null  float64
#  7   roi_netpos        88863 non-null  float64
#  8   DeliveryDate      88863 non-null  datetime64[ns]
#  9   DeliveryHour      88863 non-null  int64
#  10  DeliveryInterval  88863 non-null  int64
#  11  semo_vols         88863 non-null  float64
#  12  doy               88863 non-null  int64
#  13  dow               88863 non-null  int64
#  14  week              88863 non-null  int64
#  15  dom               88863 non-null  int64
#  16  Month             88863 non-null  datetime64[ns]
#  17  year              88863 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(7), object(2)
# memory usage: 12.2+ MB
# None

# %%
print(auctions_to_2.info()) # non-null count demonstrates there are no missing records from the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52353 entries, 0 to 52352
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   auction           52353 non-null  object
#  1   timestamp         52353 non-null  object
#  2   price_eur         52353 non-null  float64
#  3   price_gbp         52353 non-null  float64
#  4   ni_vols           52353 non-null  float64
#  5   ni_netpos         52353 non-null  float64
#  6   roi_vols          52353 non-null  float64
#  7   roi_netpos        52353 non-null  float64
#  8   DeliveryDate      52353 non-null  datetime64[ns]
#  9   DeliveryHour      52353 non-null  int64
#  10  DeliveryInterval  52353 non-null  int64
#  11  semo_vols         52353 non-null  float64
#  12  doy               52353 non-null  int64
#  13  dow               52353 non-null  int64
#  14  week              52353 non-null  int64
#  15  dom               52353 non-null  int64
#  16  Month             52353 non-null  datetime64[ns]
#  17  year              52353 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(7), object(2)
# memory usage: 7.2+ MB
# None

# %%
auctions_to = pd.concat([auctions_to_1,auctions_to_2], ignore_index=True)

# %%
print(auctions_to.head())#check the data format 
print(auctions_to.tail())
# Out:
#   auction             timestamp  price_eur  price_gbp  ni_vols  ni_netpos  \
# 0     DAM  2018-09-30T22:00:00Z     71.267     63.620    591.3     -286.0
# 1     DAM  2018-09-30T23:00:00Z     67.212     60.000    551.4     -448.4
# 2     DAM  2018-10-01T00:00:00Z     60.500     54.008    512.7     -432.2
# 3     DAM  2018-10-01T01:00:00Z     63.682     56.848    525.3     -464.0
# 4     DAM  2018-10-01T02:00:00Z     71.617     63.932    501.4     -446.6
#
#    roi_vols  roi_netpos DeliveryDate  DeliveryHour  DeliveryInterval  \
# 0    2489.9      -215.7   2018-10-01             1                 1
# 1    2709.7      -457.1   2018-10-01             2                 1
# 2    2480.2      -473.3   2018-10-01             3                 1
# 3    2397.0      -438.4   2018-10-01             4                 1
# 4    2376.4      -220.0   2018-10-01             5                 1
#
#    semo_vols  doy  dow  week  dom      Month  year
# 0     3081.2  274    1    40    1 2018-10-01  2018
# 1     3261.1  274    1    40    1 2018-10-01  2018
# 2     2992.9  274    1    40    1 2018-10-01  2018
# 3     2922.3  274    1    40    1 2018-10-01  2018
# 4     2877.8  274    1    40    1 2018-10-01  2018
#        auction             timestamp  price_eur  price_gbp  ni_vols  \
# 141211    IDA3  2022-04-30T19:30:00Z     84.388     70.950     30.0
# 141212    IDA3  2022-04-30T20:00:00Z     84.388     70.950     22.4
# 141213    IDA3  2022-04-30T20:30:00Z     60.000     50.446     21.4
# 141214    IDA3  2022-04-30T21:00:00Z     50.000     42.038     21.2
# 141215    IDA3  2022-04-30T21:30:00Z     41.000     34.471     21.2
#
#         ni_netpos  roi_vols  roi_netpos DeliveryDate  DeliveryHour  \
# 141211      -10.9     182.4        10.9   2022-04-30            22
# 141212       -9.2      45.1         9.2   2022-04-30            23
# 141213       -8.9      42.8         8.9   2022-04-30            23
# 141214       -8.2      41.6         8.2   2022-04-30            24
# 141215       -7.3      45.7         7.3   2022-04-30            24
#
#         DeliveryInterval  semo_vols  doy  dow  week  dom      Month  year
# 141211                 2      212.4  120    6    18   30 2022-04-01  2022
# 141212                 1       67.5  120    6    18   30 2022-04-01  2022
# 141213                 2       64.2  120    6    18   30 2022-04-01  2022
# 141214                 1       62.8  120    6    18   30 2022-04-01  2022
# 141215                 2       66.9  120    6    18   30 2022-04-01  2022

# %%
# Print the shape of auctions_to
print(auctions_to.shape)
# Out:
# (141216, 18)

# %%
# Print information about auctions_to
print(auctions_to.info()) # non-null count demonstrates there are no missing records from the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141216 entries, 0 to 141215
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   auction           141216 non-null  object
#  1   timestamp         141216 non-null  object
#  2   price_eur         141216 non-null  float64
#  3   price_gbp         141216 non-null  float64
#  4   ni_vols           141216 non-null  float64
#  5   ni_netpos         141216 non-null  float64
#  6   roi_vols          141216 non-null  float64
#  7   roi_netpos        141216 non-null  float64
#  8   DeliveryDate      141216 non-null  datetime64[ns]
#  9   DeliveryHour      141216 non-null  int64
#  10  DeliveryInterval  141216 non-null  int64
#  11  semo_vols         141216 non-null  float64
#  12  doy               141216 non-null  int64
#  13  dow               141216 non-null  int64
#  14  week              141216 non-null  int64
#  15  dom               141216 non-null  int64
#  16  Month             141216 non-null  datetime64[ns]
#  17  year              141216 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(7), object(2)
# memory usage: 19.4+ MB
# None

# %%
#will replace missing values with zero anyway should updates to the data set ever have missing data. 
auctions_to.fillna(0)
# Print the shape of auctions_to
print(auctions_to.shape)
# Out:
# (141216, 18)

# %%
print(auctions_to.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141216 entries, 0 to 141215
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   auction           141216 non-null  object
#  1   timestamp         141216 non-null  object
#  2   price_eur         141216 non-null  float64
#  3   price_gbp         141216 non-null  float64
#  4   ni_vols           141216 non-null  float64
#  5   ni_netpos         141216 non-null  float64
#  6   roi_vols          141216 non-null  float64
#  7   roi_netpos        141216 non-null  float64
#  8   DeliveryDate      141216 non-null  datetime64[ns]
#  9   DeliveryHour      141216 non-null  int64
#  10  DeliveryInterval  141216 non-null  int64
#  11  semo_vols         141216 non-null  float64
#  12  doy               141216 non-null  int64
#  13  dow               141216 non-null  int64
#  14  week              141216 non-null  int64
#  15  dom               141216 non-null  int64
#  16  Month             141216 non-null  datetime64[ns]
#  17  year              141216 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(7), object(2)
# memory usage: 19.4+ MB
# None

# %%
# Print a description of auctions_to
print(auctions_to.describe())
# Out:
#            price_eur      price_gbp        ni_vols      ni_netpos  \
# count  141216.000000  141216.000000  141216.000000  141216.000000
# mean       90.908566      78.290251     239.031928     -29.737785
# std        81.475815      68.456494     384.308675     148.145211
# min       -48.510000     -40.702000       0.000000   -1013.400000
# 25%        39.970000      35.150000       7.100000     -28.500000
# 50%        60.000000      52.718000      27.600000      -0.400000
# 75%       111.000000      96.412500     223.000000      14.300000
# max       757.680000     683.826000    1755.000000     898.100000
#
#             roi_vols     roi_netpos   DeliveryHour  DeliveryInterval  \
# count  141216.000000  141216.000000  141216.000000     141216.000000
# mean      985.968022      19.548403      14.832172          1.388851
# std      1469.481662     296.130049       6.817874          0.487491
# min         2.000000   -1280.300000       1.000000          1.000000
# 25%        98.800000     -51.700000       9.000000          1.000000
# 50%       197.900000       0.800000      16.000000          1.000000
# 75%       800.125000      86.900000      21.000000          2.000000
# max      5883.400000    1509.200000      25.000000          2.000000
#
#            semo_vols            doy            dow           week  \
# count  141216.000000  141216.000000  141216.000000  141216.000000
# mean     1224.999950     181.525075       3.002294      26.361340
# std      1845.639523     110.321092       1.999050      15.761524
# min         2.200000       1.000000       0.000000       1.000000
# 25%       113.400000      82.000000       1.000000      12.000000
# 50%       232.600000     179.000000       3.000000      26.000000
# 75%       963.325000     284.000000       5.000000      41.000000
# max      7442.600000     366.000000       6.000000      53.000000
#
#                  dom           year
# count  141216.000000  141216.000000
# mean       15.718049    2020.042573
# std         8.795683       1.097660
# min         1.000000    2018.000000
# 25%         8.000000    2019.000000
# 50%        16.000000    2020.000000
# 75%        23.000000    2021.000000
# max        31.000000    2022.000000

# %%
auction_type = auctions_to.drop_duplicates(subset = "auction") #check how many unique auction types there are and count 
auction_count = auction_type["auction"].value_counts(sort = True)
print(auction_count)
# Out:
# IDA3    1
# IDA1    1
# IDA2    1
# DAM     1
# Name: auction, dtype: int64

# %%
sns.countplot(x = "auction", data = auctions_to, palette = "bright")
sns.set_theme(style="dark")

plt.title("Count of Auctions by Type in Dataset")
plt.xlabel("Auction Type") # add x label
plt.ylabel("Count") # add y labe
plt.show()

# %%
auction_periods = auctions_to[auctions_to["DeliveryDate"] == "2021-01-01"]

sns.countplot(x = "DeliveryHour", data = auction_periods, hue="auction", palette = "bright")
sns.set_theme(style="dark")
sns.set(rc = {'figure.figsize':(12,6)})

plt.title("Number of Trading Periods per Delivery Day by Auction")
plt.xlabel("Delivery Hour") # add x label
plt.ylabel("Number of Periods") # add y label
plt.show()

#this shows us that the DAM auction is comprised of 24 1 hour periods from 1-24
#IDA1 is comprised of 48 half hour periods from 1-24
#IDA2 is comprised of 24 half hour periods from 13-24
#IDA3 is comprised of 48 half hour periods from 19-24

# %%
#calculate average price of energy in all auctions 
price_auctions_all = round(auctions_to["price_eur"].mean(),2)
print(price_auctions_all)

#calculate average price of energy in the DAM auction
price_auction_DAM = round(auctions_to[auctions_to["auction"] == "DAM"]["price_eur"].mean(),2)
print(price_auction_DAM)

#calculate average price of energy in the DAM auction
price_auction_IDA1 = round(auctions_to[auctions_to["auction"] == "IDA1"]["price_eur"].mean(),2)
print(price_auction_IDA1)

#calculate average price of energy in the DAM auction
price_auction_IDA2 = round(auctions_to[auctions_to["auction"] == "IDA2"]["price_eur"].mean(),2)
print(price_auction_IDA2)

#calculate average price of energy in the DAM auction
price_auction_IDA3 = round(auctions_to[auctions_to["auction"] == "IDA3"]["price_eur"].mean(),2)
print(price_auction_IDA3)
# Out:
# 90.91
# 88.08
# 86.7
# 96.78
# 101.7

# %%
#calculate total volume of energy in all auctions 
volume_auctions_all = auctions_to["semo_vols"].sum()
print(round(volume_auctions_all, 2))

#calculate total volume of energy in the DAM auction
volume_auction_DAM = round(auctions_to[auctions_to["auction"] == "DAM"]["semo_vols"].sum(),2)
print(volume_auction_DAM)

#calculate total volume of energy in the DAM auction
volume_auction_IDA1 = round(auctions_to[auctions_to["auction"] == "IDA1"]["semo_vols"].sum(),2)
print(volume_auction_IDA1)

#calculate total volume of energy in the DAM auction
volume_auction_IDA2 = round(auctions_to[auctions_to["auction"] == "IDA2"]["semo_vols"].sum(),2)
print(volume_auction_IDA2)

#calculate total volume of energy in the DAM auction
volume_auction_IDA3 = round(auctions_to[auctions_to["auction"] == "IDA3"]["semo_vols"].sum(),2)
print(volume_auction_IDA3)
# Out:
# 172989593.0
# 143607543.2
# 22651289.7
# 5139340.4
# 1591419.7

# %%
dict = {
    "Average Price":[price_auction_DAM, price_auction_IDA1, price_auction_IDA2, price_auction_IDA3],
    "Volume Traded":[volume_auction_DAM, volume_auction_IDA1, volume_auction_IDA2, volume_auction_IDA3]
}

# %%
auction_compare = pd.DataFrame(dict)
auction_compare.index = ["DAM", "IDA1", "IDA2", "IDA3"]
auction_compare
# Out:
#       Average Price  Volume Traded
# DAM           88.08    143607543.2
# IDA1          86.70     22651289.7
# IDA2          96.78      5139340.4
# IDA3         101.70      1591419.7

# %%
#print a summary of the average price and corresponding traded volume with appropriate units

for lab,row in auction_compare.iterrows() : 
    print("The " + lab + " Average Price is €" + str(row["Average Price"]) + " and the volume traded is " + str(row["Volume Traded"]) + "MWh")
# Out:
# The DAM Average Price is €88.08 and the volume traded is 143607543.2MWh
# The IDA1 Average Price is €86.7 and the volume traded is 22651289.7MWh
# The IDA2 Average Price is €96.78 and the volume traded is 5139340.4MWh
# The IDA3 Average Price is €101.7 and the volume traded is 1591419.7MWh

# %%
#will now try create some pivot tables and visulaise the data to draw insights from raw data

# %%
avg_price_monthly = auctions_to[auctions_to["auction"] == "DAM"].groupby("Month")["price_eur"].mean()

avg_price_monthly.plot(kind="line", 
                              title= "Average SEM Wholesale Electricity Price")
plt.ylabel("€/MWh")
plt.show()

# %%
#how do the energy prices vary by auction and month using matplotlib 

#pivot by month and subset by auction for DAM
DAM_avg = auctions_to[auctions_to["auction"] == "DAM"].groupby("Month")["price_eur"].mean().plot(label = "DAM")
#pivot by month and subset by auction for IDA1
IDA1_avg = auctions_to[auctions_to["auction"] == "IDA1"].groupby("Month")["price_eur"].mean().plot(label = "IDA1")
#pivot by month and subset by auction for IDA2
IDA2_avg = auctions_to[auctions_to["auction"] == "IDA2"].groupby("Month")["price_eur"].mean().plot(label = "IDA2")
#pivot by month and subset by auction for IDA3
IDA3_avg = auctions_to[auctions_to["auction"] == "IDA3"].groupby("Month")["price_eur"].mean().plot(label = "IDA3")



plt.legend() #add legend 
plt.xlabel("Month") # add x label
plt.ylabel("€/MWh") # add y label 
plt.title("Average SEM Wholesale Electricity Price") #add chart title 
plt.grid(True) # add gridlines to help interpret price points 
plt.show() # display plot

# %%
#energy prices are increasing due to the current energy crisis, are traded volumes reacting to the increase in prices? 

DAM_traded_vol = auctions_to[auctions_to["auction"] == "DAM"].groupby("Month")["semo_vols"].sum()


Months = ["Oct-18", "Nov-18", "Dec-18", "Jan-19", "Feb-19", "Mar-19", "Apr-19", "May-19", "Jun-19", "Jul-19", "Aug-19", "Sep-19", "Oct-19", "Nov-19", "Dec-19", "Jan-20", "Feb-20", "Mar-20", "Apr-20", "May-20", "Jun-20", "Jul-20", "Aug-20", "Sep-20", "Oct-20", "Nov-20", "Dec-20", "Jan-21", "Feb-21", "Mar-21", "Apr-21", "May-21", "Jun-21", "Jul-21", "Aug-21", "Sep-21", "Oct-21", "Nov-21", "Dec-21", "Jan-22", "Feb-22", "Mar-22", "Apr-22"]
sns.barplot(x= Months, y = DAM_traded_vol, palette="Set2")
sns.set(rc = {'figure.figsize':(18,9)})
sns.set_theme(style="dark")


plt.title("DAM Monthly Traded Volume")
plt.xlabel("Month") # add x label
plt.ylabel("MWh") # add y label
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain', axis='y')


plt.show()

# %%
IDA1_traded_vol = auctions_to[auctions_to["auction"] == "IDA1"].groupby("Month")["semo_vols"].sum()


Months = ["Oct-18", "Nov-18", "Dec-18", "Jan-19", "Feb-19", "Mar-19", "Apr-19", "May-19", "Jun-19", "Jul-19", "Aug-19", "Sep-19", "Oct-19", "Nov-19", "Dec-19", "Jan-20", "Feb-20", "Mar-20", "Apr-20", "May-20", "Jun-20", "Jul-20", "Aug-20", "Sep-20", "Oct-20", "Nov-20", "Dec-20", "Jan-21", "Feb-21", "Mar-21", "Apr-21", "May-21", "Jun-21", "Jul-21", "Aug-21", "Sep-21", "Oct-21", "Nov-21", "Dec-21", "Jan-22", "Feb-22", "Mar-22", "Apr-22"]
sns.barplot(x= Months, y = IDA1_traded_vol, palette="Set2")
sns.set(rc = {'figure.figsize':(18,9)})
sns.set_theme(style="dark")

plt.title("IDA1 Monthly Traded Volume")
plt.xlabel("Month") # add x label
plt.ylabel("MWh") # add y label
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain', axis='y')


plt.show()

# %%
IDA2_traded_vol = auctions_to[auctions_to["auction"] == "IDA2"].groupby("Month")["semo_vols"].sum()


Months = ["Oct-18", "Nov-18", "Dec-18", "Jan-19", "Feb-19", "Mar-19", "Apr-19", "May-19", "Jun-19", "Jul-19", "Aug-19", "Sep-19", "Oct-19", "Nov-19", "Dec-19", "Jan-20", "Feb-20", "Mar-20", "Apr-20", "May-20", "Jun-20", "Jul-20", "Aug-20", "Sep-20", "Oct-20", "Nov-20", "Dec-20", "Jan-21", "Feb-21", "Mar-21", "Apr-21", "May-21", "Jun-21", "Jul-21", "Aug-21", "Sep-21", "Oct-21", "Nov-21", "Dec-21", "Jan-22", "Feb-22", "Mar-22", "Apr-22"]
sns.barplot(x= Months, y = IDA2_traded_vol, palette="Set2")
sns.set(rc = {'figure.figsize':(18,9)})
sns.set_theme(style="dark")

plt.title("IDA2 Monthly Traded Volume")
plt.xlabel("Month") # add x label
plt.ylabel("MWh") # add y label
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain', axis='y')


plt.show()

# %%
IDA3_traded_vol = auctions_to[auctions_to["auction"] == "IDA3"].groupby("Month")["semo_vols"].sum()


Months = ["Oct-18", "Nov-18", "Dec-18", "Jan-19", "Feb-19", "Mar-19", "Apr-19", "May-19", "Jun-19", "Jul-19", "Aug-19", "Sep-19", "Oct-19", "Nov-19", "Dec-19", "Jan-20", "Feb-20", "Mar-20", "Apr-20", "May-20", "Jun-20", "Jul-20", "Aug-20", "Sep-20", "Oct-20", "Nov-20", "Dec-20", "Jan-21", "Feb-21", "Mar-21", "Apr-21", "May-21", "Jun-21", "Jul-21", "Aug-21", "Sep-21", "Oct-21", "Nov-21", "Dec-21", "Jan-22", "Feb-22", "Mar-22", "Apr-22"]
sns.barplot(x= Months, y = IDA3_traded_vol, palette="Set2")
sns.set(rc = {'figure.figsize':(18,9)})
sns.set_theme(style="dark")

plt.title("IDA3 Monthly Traded Volume")
plt.xlabel("Month") # add x label
plt.ylabel("MWh") # add y label
plt.xticks(rotation = 90)
plt.ticklabel_format(style='plain', axis='y')


plt.show()
